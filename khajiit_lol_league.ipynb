# %% [markdown]
# <a href="https://colab.research.google.com/github/snaiws/Project-2/blob/main/khajiit_lol_league.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # import

# %%
from bs4 import BeautifulSoup
import urllib
import pandas as pd
import numpy as np

# %% [markdown]
# # 카짓1

# %%
def khajiit_1(url,league): #khajiit1 is for scoreboard
  soup = BeautifulSoup(urllib.request.urlopen(url).read(), 'html.parser')

  date=soup.find_all('span',class_="DateInLocal")
  def f_date(z):
    y=list()
    m=list()
    d=list()
    for i in range(len(z)):
      b=str(z[i])
      b=b[b.find('>'):]
      b=b[1:]
      b=b[:b.find('<')]
      y.append(b[0:4])
      b=b[b.find(','):]
      b=b[1:]
      c=b[::-1]
      c=c[9:]
      c=c[::-1]
      m.append(c)
      b=b[b.find(','):]
      b=b[1:]
      b=b[::-1]
      b=b[6:]
      b=b[::-1]
      d.append(b)
      z[i]=f'{y[i]}-{m[i]}-{d[i]}'
    return z
  date=f_date(date)

  champion=soup.find_all('div',class_="sb-p-champion")
  def f_champ(z):
    for i in range(len(z)):
      a=str(z[i])
      z[i]=a[a.find('title="'):a.find('"><br/></span></div>')]
      z[i]=z[i][7:]
    return z
  f_champ(champion)
  BTC=[champion[10*i] for i in range(int(len(champion)/10))]
  BJC=[champion[10*i+1] for i in range(int(len(champion)/10))]
  BMC=[champion[10*i+2] for i in range(int(len(champion)/10))]
  BAC=[champion[10*i+3] for i in range(int(len(champion)/10))]
  BSC=[champion[10*i+4] for i in range(int(len(champion)/10))]
  RTC=[champion[10*i+5] for i in range(int(len(champion)/10))]
  RJC=[champion[10*i+6] for i in range(int(len(champion)/10))]
  RMC=[champion[10*i+7] for i in range(int(len(champion)/10))]
  RAC=[champion[10*i+8] for i in range(int(len(champion)/10))]
  RSC=[champion[10*i+9] for i in range(int(len(champion)/10))]

  name=soup.find_all('div',class_="sb-p-name")
  def f_name1(z):
    for i in range(len(z)):
      a=str(z[i])
      z[i]=a[a.find('Tooltip:'):a.find('" href')]
      z[i]=z[i][8:]
    return z

  def f_name2(z):
    for i in range(len(z)):
      a=str(z[i])
      a=a[a.find('title'):]
      a=a[a.find('>'):]
      a=a[1:]
      a=a[::-1]
      a=a[10:]
      a=a[::-1]
      z[i]=a
    return z
  f_name2(name)
  BT=[name[10*i] for i in range(int(len(name)/10))]
  BJ=[name[10*i+1] for i in range(int(len(name)/10))]
  BM=[name[10*i+2] for i in range(int(len(name)/10))]
  BA=[name[10*i+3] for i in range(int(len(name)/10))]
  BS=[name[10*i+4] for i in range(int(len(name)/10))]
  RT=[name[10*i+5] for i in range(int(len(name)/10))]
  RJ=[name[10*i+6] for i in range(int(len(name)/10))]
  RM=[name[10*i+7] for i in range(int(len(name)/10))]
  RA=[name[10*i+8] for i in range(int(len(name)/10))]
  RS=[name[10*i+9] for i in range(int(len(name)/10))]

  team=soup.find_all('span',class_="teamname")
  def f_team(z):
    for i in range(len(z)):
      a=str(z[i])
      a=a[a.find('</a>'):a.find('" title="'):-1]
      a=a[::-1]
      a=a[a.find('>'):a.find('<')]
      z[i]=a[1:]
    return z
  f_team(team)
  Blue=[team[2*i] for i in range(int(len(team)/2))]
  Red=[team[2*i+1] for i in range(int(len(team)/2))]

  kda=soup.find_all('div',class_="sb-p-stat sb-p-stat-kda")
  def f_kda(z):
    for i in range(len(z)):
      a=str(z[i])
      a=a[a.find('>'):]
      z[i]=a[1:a.find('<')]
    return z
  f_kda(kda)
  def cal_kda(z):
    K=list()
    D=list()
    A=list()
    for i in range(len(z)):
      q=z[i]
      k=int(q[:q.find('/')])
      d=q[q.find('/'):]
      d=d[1:]
      d=int(d[:d.find('/')])
      a=q[q.find('/'):]
      a=a[1:]
      a=a[a.find('/'):]
      a=int(a[1:])
      K.append(k)
      D.append(d)
      A.append(a)
    return K,D,A
  K,D,A=cal_kda(kda)
  BTK=[K[10*i] for i in range(int(len(K)/10))]
  BJK=[K[10*i+1] for i in range(int(len(K)/10))]
  BMK=[K[10*i+2] for i in range(int(len(K)/10))]
  BAK=[K[10*i+3] for i in range(int(len(K)/10))]
  BSK=[K[10*i+4] for i in range(int(len(K)/10))]
  RTK=[K[10*i+5] for i in range(int(len(K)/10))]
  RJK=[K[10*i+6] for i in range(int(len(K)/10))]
  RMK=[K[10*i+7] for i in range(int(len(K)/10))]
  RAK=[K[10*i+8] for i in range(int(len(K)/10))]
  RSK=[K[10*i+9] for i in range(int(len(K)/10))]

  BTD=[D[10*i] for i in range(int(len(D)/10))]
  BJD=[D[10*i+1] for i in range(int(len(D)/10))]
  BMD=[D[10*i+2] for i in range(int(len(D)/10))]
  BAD=[D[10*i+3] for i in range(int(len(D)/10))]
  BSD=[D[10*i+4] for i in range(int(len(D)/10))]
  RTD=[D[10*i+5] for i in range(int(len(D)/10))]
  RJD=[D[10*i+6] for i in range(int(len(D)/10))]
  RMD=[D[10*i+7] for i in range(int(len(D)/10))]
  RAD=[D[10*i+8] for i in range(int(len(D)/10))]
  RSD=[D[10*i+9] for i in range(int(len(D)/10))]

  BTA=[A[10*i] for i in range(int(len(A)/10))]
  BJA=[A[10*i+1] for i in range(int(len(A)/10))]
  BMA=[A[10*i+2] for i in range(int(len(A)/10))]
  BAA=[A[10*i+3] for i in range(int(len(A)/10))]
  BSA=[A[10*i+4] for i in range(int(len(A)/10))]
  RTA=[A[10*i+5] for i in range(int(len(A)/10))]
  RJA=[A[10*i+6] for i in range(int(len(A)/10))]
  RMA=[A[10*i+7] for i in range(int(len(A)/10))]
  RAA=[A[10*i+8] for i in range(int(len(A)/10))]
  RSA=[A[10*i+9] for i in range(int(len(A)/10))]

  win=soup.find_all('div',class_=("sb-header-vertict"))
  def f_bw(z):
    for i in range(len(z)):
      a=str(z[i])
      a=a[a.find('>'):]
      z[i]=a[1:a.find('<')]
    a=list()
    for i in range(int(len(z)/2)):
      j=i*2
      a.append(z[j])
    for i in range(len(a)):
      try: 
        a[i]=int(a[i].replace('Defeat','0').replace('Victory','1'))
      except:
        a[i]=np.nan
    return a
  win=f_bw(win)

  gold=soup.find_all('div',class_=("sb-p-stat sb-p-stat-gold"))
  def f_g(z):
    for i in range(len(z)):
      a=str(z[i])
      a=a[a.find('>'):]
      z[i]=a[1:a.find('<')]
    for i in range(len(z)):
      try:
        z[i]=float(str(z[i]).replace('k',''))
      except:
        z[i]=np.nan
    return z
  f_g(gold)

  BTG=[gold[10*i] for i in range(int(len(gold)/10))]
  BJG=[gold[10*i+1] for i in range(int(len(gold)/10))]
  BMG=[gold[10*i+2] for i in range(int(len(gold)/10))]
  BAG=[gold[10*i+3] for i in range(int(len(gold)/10))]
  BSG=[gold[10*i+4] for i in range(int(len(gold)/10))]
  RTG=[gold[10*i+5] for i in range(int(len(gold)/10))]
  RJG=[gold[10*i+6] for i in range(int(len(gold)/10))]
  RMG=[gold[10*i+7] for i in range(int(len(gold)/10))]
  RAG=[gold[10*i+8] for i in range(int(len(gold)/10))]
  RSG=[gold[10*i+9] for i in range(int(len(gold)/10))]

  cs=soup.find_all('div',class_=("sb-p-stat sb-p-stat-cs"))
  def f_cs(z):
    for i in range(len(z)):
      a=str(z[i])
      a=a[a.find('>'):]
      try:
        z[i]=int(a[1:a.find('<')])
      except:
        z[i]=np.nan
    return z
  f_cs(cs)

  BTCS=[cs[10*i] for i in range(int(len(cs)/10))]
  BJCS=[cs[10*i+1] for i in range(int(len(cs)/10))]
  BMCS=[cs[10*i+2] for i in range(int(len(cs)/10))]
  BACS=[cs[10*i+3] for i in range(int(len(cs)/10))]
  BSCS=[cs[10*i+4] for i in range(int(len(cs)/10))]
  RTCS=[cs[10*i+5] for i in range(int(len(cs)/10))]
  RJCS=[cs[10*i+6] for i in range(int(len(cs)/10))]
  RMCS=[cs[10*i+7] for i in range(int(len(cs)/10))]
  RACS=[cs[10*i+8] for i in range(int(len(cs)/10))]
  RSCS=[cs[10*i+9] for i in range(int(len(cs)/10))]

  df=pd.DataFrame()
  df['date']=date
  df['Blue']=Blue
  df['Red']=Red
  df['winner']=win
  df['BT']=BT
  df['BTC']=BTC
  df['BTK']=BTK
  df['BTD']=BTD
  df['BTA']=BTA
  df['BTCS']=BTCS
  df['BTG']=BTG
  df['BJ']=BJ
  df['BJC']=BJC
  df['BJK']=BJK
  df['BJD']=BJD
  df['BJA']=BJA
  df['BJCS']=BJCS
  df['BJG']=BJG
  df['BM']=BM
  df['BMC']=BMC
  df['BMK']=BMK
  df['BMD']=BMD
  df['BMA']=BMA
  df['BMCS']=BMCS
  df['BMG']=BMG
  df['BA']=BA
  df['BAC']=BAC
  df['BAK']=BAK
  df['BAD']=BAD
  df['BAA']=BAA
  df['BACS']=BACS
  df['BAG']=BAG
  df['BS']=BS
  df['BSC']=BSC
  df['BSK']=BSK
  df['BSD']=BSD
  df['BSA']=BSA
  df['BSCS']=BSCS
  df['BSG']=BSG
  df['RT']=RT
  df['RTC']=RTC
  df['RTK']=RTK
  df['RTD']=RTD
  df['RTA']=RTA
  df['RTCS']=RTCS
  df['RTG']=RTG
  df['RJ']=RJ
  df['RJC']=RJC
  df['RJK']=RJK
  df['RJD']=RJD
  df['RJA']=RJA
  df['RJCS']=RJCS
  df['RJG']=RJG
  df['RM']=RM
  df['RMC']=RMC
  df['RMK']=RMK
  df['RMD']=RMD
  df['RMA']=RMA
  df['RMCS']=RMCS
  df['RMG']=RMG
  df['RA']=RA
  df['RAC']=RAC
  df['RAK']=RAK
  df['RAD']=RAD
  df['RAA']=RAA
  df['RACS']=RACS
  df['RAG']=RAG
  df['RS']=RS
  df['RSC']=RSC
  df['RSK']=RSK
  df['RSD']=RSD
  df['RSA']=RSA
  df['RSCS']=RSCS
  df['RSG']=RSG
  b=list()
  for i in range(len(df)):
    b.append(league)
  b=pd.DataFrame(b,columns=['league'])
  df=pd.concat([b,df],axis=1)
  return df

# %% [markdown]
# # apply

# %%
league='2017RiftRivals'


url1='https://lol.fandom.com/wiki/Rift_Rivals_2017/LCK-LPL-LMS/Scoreboards'
url2='https://lol.fandom.com/wiki/Rift_Rivals_2017/NA-EU/Scoreboards'
url3='https://lol.fandom.com/wiki/Rift_Rivals_2017/LLN-CLS-CBLOL/Scoreboards'
url4='https://lol.fandom.com/wiki/Rift_Rivals_2017/LCL-TCL/Scoreboards'
url5='https://lol.fandom.com/wiki/Rift_Rivals_2017/GPL-LJL-OPL/Scoreboards'
url6='https://lol.fandom.com/wiki/Rift_Rivals_2017/GPL-LJL-OPL/Scoreboards/Finals'

df1=khajiit_1(url1,league)
df2=khajiit_1(url2,league)
df3=khajiit_1(url3,league)
df4=khajiit_1(url4,league)
df5=khajiit_1(url5,league)
df6=khajiit_1(url6,league)

df1=pd.concat([df1,df2])
df1=pd.concat([df1,df3])
df1=pd.concat([df1,df4])
df1=pd.concat([df1,df5])
df1=pd.concat([df1,df6])



df1.reset_index(inplace=True)
df1=df1.drop('index',axis=1)
df1.to_csv(f'{league}.csv', index=False)

# %%
league='2019RiftRivals'


url1='https://lol.fandom.com/wiki/Rift_Rivals_2019/LCK-LPL-LMS-VCS/Scoreboards'
url2='https://lol.fandom.com/wiki/Rift_Rivals_2019/LCK-LPL-LMS-VCS/Scoreboards/Bracket_Stage'
url3='https://lol.fandom.com/wiki/Rift_Rivals_2019/NA-EU/Scoreboards'
url4='https://lol.fandom.com/wiki/Rift_Rivals_2019/NA-EU/Scoreboards/Finals'
df1=khajiit_1(url1,league)
df2=khajiit_1(url2,league)
df3=khajiit_1(url3,league)
df4=khajiit_1(url4,league)

df1=pd.concat([df1,df2])
df1=pd.concat([df1,df3])
df1=pd.concat([df1,df4])

df1.reset_index(inplace=True)
df1=df1.drop('index',axis=1)
df1.to_csv(f'{league}.csv', index=False)

# %%
league='2019ALSPRINGPLAYOFF'
url1='https://lol.fandom.com/wiki/NA_Academy_League/2019_Season/Spring_Playoffs/Scoreboards'
df1=khajiit_1(url1,league)
df1.to_csv(f'{league}.csv', index=False)

# %%
#2016ckspring 3,4,7 오류
#2019CKSPRING 2
#2013LPLSUMMERPLAYOFF
#LDL/2021_Season/Spring_Season/Week_7(3)
#https://lol.fandom.com/wiki/EU_LCS/Season_3/Spring_Playoffs/Scoreboards
#https://lol.fandom.com/wiki/EU_LCS/2014_Season/Summer_Season/Scoreboards/Week_4
#https://lol.fandom.com/wiki/EU_Challenger_Series/2014_Season/Spring_Series_2/Scoreboards
'https://lol.fandom.com/wiki/EU_Challenger_Series/2017_Season/Summer_Qualifiers/Scoreboards'
#https://lol.fandom.com/wiki/European_Masters/2018_Season/Spring/Play-In/Scoreboards

# %%
df1
# Out:
#      league       date           Blue            Red  ...  RSD RSA RSCS   RSG
# 0   2016MSI  2016-5-04            RNG            CLG  ...    6  20   44  11.4
# 1   2016MSI  2016-5-04     G2 Esports   Flash Wolves  ...    2  15   50  11.9
# 2   2016MSI  2016-5-04  SK Telecom T1   SuperMassive  ...    5   1   31   6.1
# 3   2016MSI  2016-5-04            CLG   Flash Wolves  ...    4  11   46  12.5
# 4   2016MSI  2016-5-04     G2 Esports  SK Telecom T1  ...    3  15   21   7.6
# 5   2016MSI  2016-5-04   SuperMassive            RNG  ...    2  14   51  10.8
# 6   2016MSI  2016-5-05            CLG     G2 Esports  ...    5   0   14   6.2
# 7   2016MSI  2016-5-05  SK Telecom T1            RNG  ...    3  16   67  15.6
# 8   2016MSI  2016-5-05   Flash Wolves   SuperMassive  ...    4   2   48   7.2
# 9   2016MSI  2016-5-05            RNG     G2 Esports  ...    4   3   33   7.8
# 10  2016MSI  2016-5-05   SuperMassive            CLG  ...    5   5   41   7.4
# 11  2016MSI  2016-5-05  SK Telecom T1   Flash Wolves  ...    0   8   40  12.9
# 12  2016MSI  2016-5-06   Flash Wolves            RNG  ...    1   6   33   8.3
# 13  2016MSI  2016-5-06            CLG  SK Telecom T1  ...    3  14   57  11.7
# 14  2016MSI  2016-5-06   SuperMassive     G2 Esports  ...    3  20   17  11.4
# 15  2016MSI  2016-5-06   Flash Wolves  SK Telecom T1  ...    2   2   64   9.6
# 16  2016MSI  2016-5-06            CLG   SuperMassive  ...    4   3   37   6.7
# 17  2016MSI  2016-5-06     G2 Esports            RNG  ...    1   5   47  10.3
# 18  2016MSI  2016-5-07     G2 Esports   SuperMassive  ...    4   2   19   7.0
# 19  2016MSI  2016-5-07            RNG   Flash Wolves  ...    4   2   14   6.3
# 20  2016MSI  2016-5-07  SK Telecom T1            CLG  ...    3   7   20   8.6
# 21  2016MSI  2016-5-07   Flash Wolves     G2 Esports  ...    3   3   45   9.1
# 22  2016MSI  2016-5-07            CLG            RNG  ...    6   6   33  11.1
# 23  2016MSI  2016-5-07   SuperMassive  SK Telecom T1  ...    4  15   35   8.4
# 24  2016MSI  2016-5-07     G2 Esports   SuperMassive  ...    2   7   39   NaN
# 25  2016MSI  2016-5-08            RNG   SuperMassive  ...    2   5   26   5.3
# 26  2016MSI  2016-5-08   Flash Wolves            CLG  ...    3   8   13   9.8
# 27  2016MSI  2016-5-08  SK Telecom T1     G2 Esports  ...    1   3   34   6.1
# 28  2016MSI  2016-5-08   SuperMassive   Flash Wolves  ...    0   6   47   9.2
# 29  2016MSI  2016-5-08     G2 Esports            CLG  ...    2  11   29   7.0
# 30  2016MSI  2016-5-08            RNG  SK Telecom T1  ...    7  12   80  14.4
# 31  2016MSI  2016-5-13            RNG  SK Telecom T1  ...    2  10   24   9.9
# 32  2016MSI  2016-5-13            RNG  SK Telecom T1  ...    2  14   16   8.0
# 33  2016MSI  2016-5-13            RNG  SK Telecom T1  ...    2  15   23  10.2
# 34  2016MSI  2016-5-13            RNG  SK Telecom T1  ...    0   5   14   8.2
# 35  2016MSI  2016-5-14            CLG   Flash Wolves  ...    2   3   18   7.0
# 36  2016MSI  2016-5-14            CLG   Flash Wolves  ...    1  10   15  10.0
# 37  2016MSI  2016-5-14            CLG   Flash Wolves  ...    3   8   15   9.5
# 38  2016MSI  2016-5-14            CLG   Flash Wolves  ...    2   2    6   6.4
# 39  2016MSI  2016-5-15            CLG  SK Telecom T1  ...    2  10   26   9.3
# 40  2016MSI  2016-5-15            CLG  SK Telecom T1  ...    0  11   22   9.9
# 41  2016MSI  2016-5-15            CLG  SK Telecom T1  ...    0  20   27  11.6
#
# [42 rows x 75 columns]
